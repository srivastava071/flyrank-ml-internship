# %% [markdown]
# <a href="https://colab.research.google.com/github/srivastava071/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/srivastava071/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Refresh / Content Opportunity Scoring
#
# I chose this lane because websites often contain thousands of pages, making it difficult for SEO teams to know which pages should be reviewed first. This project aims to prioritize pages that are likely to decline in search performance so they can be refreshed before losing significant traffic.
#
# I selected this lane because it builds on the work completed in the starter notebooks, where I explored search-performance data and learned how interpretable machine learning models can support better decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
#
#
# For my project, I want to identify webpages that should be refreshed before their search performance starts declining.
#
# The decision that my work supports is deciding **which webpages should be updated first**. Instead of checking every page manually, the model can help prioritize the pages that are more likely to need attention.
#
# The people who would use this are **SEO specialists or content managers**. Based on the recommendations, they can update the content, improve SEO, or refresh outdated information.
#
# If the recommendation is wrong, there are two possible outcomes:
# - If a good page is marked as needing an update, the team may spend time and effort on a page that didn't require changes.
# - If a page that is actually losing performance is missed, it may continue to lose rankings and traffic before anyone notices.
#
# I think machine learning can help because large websites have hundreds or even thousands of webpages. Checking each one manually is not practical, so using historical search data to prioritize pages can save time and help teams make better decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2–3 real numbers)
#
# Before choosing my research lane, I explored the starter dataset to understand whether it contains enough information to support this project.
#
# The dataset contains **[Total webpages]** webpages.
#
# The average click-through rate (CTR) is **[Average CTR]**, and the average search position is **[Average Position]**.
#
# These numbers show that the dataset contains useful search-performance information that can help identify webpages which may need a content refresh. This makes the Refresh / Content Opportunity Scoring lane a meaningful problem to explore over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Quick look at the dataset

import pandas as pd

# Load starter dataset
df = pd.read_csv("content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(),3))
print("Average Position:", round(df["avg_position"].mean(),2))
print("Average Content Age:", round(df["content_age_days"].mean(),1))
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Average Position: 16.34
# Average Content Age: 256.2

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# In this project, I want to build a model that helps identify webpages which may need a content refresh based on historical search-performance data.
#
# I can use the data to find patterns and provide recommendations about which pages should be reviewed first. My work is meant to support decision-making, not replace it.
#
# However, I cannot claim that updating a page will definitely improve its Google rankings or traffic. I also cannot say that one factor directly causes another, because this project is based on observed data rather than controlled experiments.
#
# My goal is to build a model that helps SEO teams make better, data-informed decisions instead of trying to predict Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅] No client names, URLs, or private queries anywhere
# - [✅] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
