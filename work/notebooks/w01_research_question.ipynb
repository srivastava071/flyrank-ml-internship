# %% [markdown]
# <a href="https://colab.research.google.com/github/srivastava071/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/srivastava071/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane: Refresh / Content Opportunity Scoring**
#
# I chose this lane because websites often contain thousands of pages, making it difficult for SEO teams to know which pages should be reviewed first. This project aims to prioritize pages that are likely to decline in search performance so they can be refreshed before losing significant traffic.
#
# I selected this lane because it builds on the work completed in the starter notebooks, where I explored search-performance data and learned how interpretable machine learning models can support better decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# My research question is:
#
# **Can historical search-performance and content signals help prioritize webpages that may need a content refresh before their search performance declines?**
#
# The decision supported by this work is deciding **which webpages should be reviewed or updated first**. Instead of checking every page manually, the model can help prioritize pages that show signals associated with declining performance.
#
# The main users would be **SEO specialists or content managers**. They could use the recommendations to decide which pages deserve human review, content updates, or SEO improvements.
#
# If the recommendation is wrong, there are two possible outcomes:
#
# - A good page may be incorrectly prioritized, causing the team to spend time reviewing a page that did not need immediate attention.
# - A page that is actually losing performance may be missed, allowing its search performance to decline further before the team notices.
#
# Machine learning may be useful because large websites can contain hundreds or thousands of webpages. Historical search data can help prioritize the pages that deserve human attention instead of requiring every page to be checked manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2–3 real numbers)
#
# Before choosing my research lane, I explored the starter dataset to understand whether it contains enough information to support this project.
#
# The dataset contains **30,000 webpages**.
#
# The average click-through rate (CTR) is **0.511**, and the average search position is **16.34**. The average content age is **256.2 days**.
#
# These observed values show that the dataset contains search-performance and content-age information that can be used to investigate which webpages may need a content refresh. This makes the Refresh / Content Opportunity Scoring lane a useful problem to explore.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Quick look at the dataset

import pandas as pd

# Load starter dataset
df = pd.read_csv("content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(),3))
print("Average Position:", round(df["avg_position"].mean(),2))
print("Average Content Age:", round(df["content_age_days"].mean(),1))
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Average Position: 16.34
# Average Content Age: 256.2

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# In this project, I want to build a model that helps identify webpages that may need a content refresh based on historical search-performance data.
#
# I can use the observed data to identify patterns and provide recommendations about which pages should be reviewed first. The output is intended to support human decision-making rather than replace it.
#
# I cannot claim that updating a page will definitely improve its Google rankings, clicks, or traffic. I also cannot claim that one feature directly causes another because this project uses observed historical data rather than a controlled experiment.
#
# The goal is to provide SEO teams with a data-informed prioritization tool rather than to predict or explain Google's search algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done
